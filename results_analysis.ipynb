# %%
import numpy as np
import pandas as pd
import ast
import matplotlib.pyplot as plt

# %%
results = pd.read_csv("results.csv")
results
# Out:
#     hidden_layer  batch_size  learning_rate  taxa_acerto  num_epochs  \
# 0             25           1            0.1     0.828619          14
# 1             25           1            0.5     0.908976          22
# 2             25           1            1.0     0.744452           7
# 3             25           1           10.0     0.099714           4
# 4             25          10            0.1     0.910333         109
# ..           ...         ...            ...          ...         ...
# 79           100        1000           10.0     0.893690          35
# 80           100        5000            0.1     0.372833        1000
# 81           100        5000            0.5     0.795833        1000
# 82           100        5000            1.0     0.814929        1000
# 83           100        5000           10.0     0.098381          11
#
#                                         training_loss  \
# 0   [2.063466645307745, 1.7232964326916134, 1.6595...
# 1   [1.8014791892466246, 1.6008651644068972, 1.582...
# 2   [1.8687129211463935, 1.7518340479399972, 1.716...
# 3   [2.342741420541341, 2.3571293650686465, 2.3571...
# 4   [2.2928619341850283, 2.2326176640987394, 2.154...
# ..                                                ...
# 79  [2.2954758644104003, 2.2798894882202148, 2.276...
# 80  [2.301765203475952, 2.3017258644104004, 2.3016...
# 81  [2.3022849559783936, 2.302067756652832, 2.3018...
# 82  [2.3028407096862793, 2.3024775981903076, 2.302...
# 83  [2.3042490482330322, 2.300602912902832, 2.2969...
#
#                                       validation_loss
# 0   [1.829925117038545, 1.6792509158452351, 1.6702...
# 1   [1.6711939232689994, 1.6109786913508461, 1.595...
# 2   [1.7914694434120542, 1.7045543931779408, 1.719...
# 3   [2.361436577070327, 2.361436577070327, 2.36143...
# 4   [2.2777300846009028, 2.2030264933904014, 2.141...
# ..                                                ...
# 79  [2.2789010888054255, 2.285550741922288, 2.2136...
# 80  [2.302180460521153, 2.302145231337774, 2.30210...
# 81  [2.303003810700916, 2.3028041067577543, 2.3026...
# 82  [2.302609540167309, 2.302313072340829, 2.30201...
# 83  [2.3008384874888828, 2.29768325033642, 2.29406...
#
# [84 rows x 7 columns]

# %%
training_loss = np.array(ast.literal_eval(results['training_loss'].iloc[82]))
validation_loss = np.array(ast.literal_eval(results['validation_loss'].iloc[82]))

plt.plot(training_loss, label="Training Loss")
plt.plot(validation_loss, label="Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training and Validation Loss")
plt.legend()
plt.show()
